# %% [markdown]
# ### Explainability Across Models
#
# To understand the drivers of churn, feature importance was analyzed using:
# - Logistic Regression (coefficients → direction of impact)
# - Random Forest (feature importance → contribution strength)
# - XGBoost (feature importance → robust non-linear patterns)
#
# This helps identify consistent churn drivers across different models.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    roc_auc_score,
    roc_curve,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# %%
X_train = pd.read_csv("X_train.csv")
X_test = pd.read_csv("X_test.csv")

y_train = pd.read_csv("y_train.csv").values.ravel()
y_test = pd.read_csv("y_test.csv").values.ravel()

# %%
X_train = X_train.astype(float)
X_test = X_test.astype(float)

# %% [markdown]
# #### Logistic Regression Feature Importance
#
# Logistic Regression coefficients indicate the direction of impact:
# - Positive → increases churn probability
# - Negative → reduces churn probability

# %%
import pandas as pd
import matplotlib.pyplot as plt

coeffs = pd.Series(log_model.coef_[0], index=X_train.columns)
coeffs_sorted = coeffs.sort_values(ascending=False)

print("Top Features Increasing Churn:")
print(coeffs_sorted.head(10))

print("\nTop Features Reducing Churn:")
print(coeffs_sorted.tail(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 coeffs = pd.Series(log_model.coef_[0], index=X_train.columns)
#       5 coeffs_sorted = coeffs.sort_values(ascending=False)
#       6
#       7 print("Top Features Increasing Churn:")
#
# NameError: name 'log_model' is not defined
